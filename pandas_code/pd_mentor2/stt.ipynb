# %%
import pandas as pd

df = pd.read_csv('sleeping_patterns.csv')
df.head(10)
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
# lst_col = []
#
# def get_name(name):
#     return '_'.join(name.lower().split())
#
# for el in df.columns:
#     name = get_name(el)
#     lst_col.append(name)
#
#
# df.columns = lst_col
# df

# %%
df.columns = df.columns.str.replace(' ', '_').str.lower()
df
# Out:
#      person_id  gender  age            occupation  sleep_duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      quality_of_sleep  physical_activity_level  stress_level bmi_category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      189
# Female    185
# Name: count, dtype: int64

# %%
df.groupby('gender')['gender'].count()
# Out:
# gender
# Female    185
# Male      189
# Name: gender, dtype: int64

# %%
df[(df['occupation'] == 'Software Engineer') & (df['gender'] == 'Male')]
# Out:
#     person_id gender  age         occupation  sleep_duration  \
# 0           1   Male   27  Software Engineer             6.1
# 5           6   Male   28  Software Engineer             5.9
# 84         85   Male   35  Software Engineer             7.5
# 92         93   Male   35  Software Engineer             7.5
#
#     quality_of_sleep  physical_activity_level  stress_level   bmi_category  \
# 0                  6                       42             6     Overweight
# 5                  4                       30             8          Obese
# 84                 8                       60             5  Normal Weight
# 92                 8                       60             5  Normal Weight
#
#    blood_pressure  heart_rate  daily_steps sleep_disorder
# 0          126/83          77         4200            NaN
# 5          140/90          85         3000       Insomnia
# 84         120/80          70         8000            NaN
# ...

# %%
df.groupby('occupation')['occupation'].count()
# Out:
# occupation
# Accountant              37
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Manager                  1
# Nurse                   73
# Sales Representative     2
# Salesperson             32
# Scientist                4
# Software Engineer        4
# Teacher                 40
# Name: occupation, dtype: int64

# %%
#топ профессии 3 от ожирения
res = df.groupby(by=['occupation', 'bmi_category'], sort=False, as_index=False).agg(count_cat=('person_id', 'count'))
res = res[res['bmi_category'] == 'Obese']
res.sort_values('count_cat', ascending=False)
# Out:
#               occupation bmi_category  count_cat
# 22                Doctor        Obese          4
# 2   Sales Representative        Obese          2
# 12                Lawyer        Obese          2
# 4                Teacher        Obese          1
# 3      Software Engineer        Obese          1
